# %%
import sys
from pathlib import Path
import os
import numpy as np

# Get the directory where this notebook is located
notebook_dir = Path(os.getcwd())
project_root = notebook_dir.parent  # Go up one level to project root
src_path = project_root / 'src'

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from cs_priors.plotting.plotting import (
    plot_equation,
    plot_two_line_equation,
    plot_overview,
    wrapper_plot_geometry,
)
from cs_priors.simulation.mixing_model import 
from cs_priors.solvers.group_lasso import group_lasso, groups_on_complex_numbers

# %% [markdown]
# # Group lasso
# Rearranging complex vectors as wide real systems
