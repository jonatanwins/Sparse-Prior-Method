# %%
# Behind the scenes

# %% [markdown]
# # Group sparse prior
# Snurrebasseksempel: kilde 1 og 2 er positivt korrelert, kilde 3 er uavhengig.

# %%
V = 1
s = 0.005

D_1 = [[V,     V,     0],
       [V,     s,     0],
       [0,     0,     s]]

D_2 = [[s,     V,     0],
       [V,     V,     0],
       [0,     0,     s]]

D_3 = [[s,     0,     0],
       [0,     s,     0],
       [0,     0,     V]]

# %% [markdown]
# ### Plot snurrebass
